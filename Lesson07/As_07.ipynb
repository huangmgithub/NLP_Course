# %% [markdown]
# # 8.25习题课
# # 1.第七周作业讲解
# # 2.项目一问题分别解答

# %% [markdown]
# # 新华社新闻抄袭

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import jieba
import scipy
import sklearn
import time, timeit
import re

# %%
data = pd.read_csv('sqlResult_1558435.csv',encoding='gb18030')

# %% [markdown]
# # look at the data

# %%
data.head(10)
# Out:
#       id      author                    source  \
# 0  89617         NaN    快科技@http://www.kkj.cn/
# 1  89616         NaN    快科技@http://www.kkj.cn/
# 2  89615         NaN    快科技@http://www.kkj.cn/
# 3  89614         NaN                       新华社
# 4  89613  胡淑丽_MN7479                     深圳大件事
# 5  89612          张怡                 中国证券报?中证网
# 6  89611         NaN  威锋网@http://www.feng.com/
# 7  89610      申玉彬 整理                 中国证券报?中证网
# 8  89609  李杭_BJS4645                 荆楚网-楚天都市报
# 9  89608          吴瞬                 中国证券报?中证网
#
#                                              content  \
# 0  此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1  骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2  此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3    这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
# 5  　　受到A股被纳入MSCI指数的利好消息刺激，A股市场从周三开始再度上演龙马行情，周四上午金...
# 6  虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是...
# 7  　　沙漠雄鹰：震荡有利消化套牢筹码\r\n　　周四开盘上证50在银行券商大蓝筹带动下一度涨近...
# 8  （原标题：武汉警方一下子抓了808人，还都是俊男靓女！原来他们每天偷偷摸摸干这事！）\r\n...
# 9  　　6月21日，A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22...
#
#                                              feature  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...
# 5  {"type":"市场","site":"中证网","commentNum":"0","jo...
# 6  {"type":"科技","site":"cnbeta","commentNum":"21"...
# 7  {"type":"市场","site":"中证网","commentNum":"0","jo...
# 8  {"type":"新闻","site":"网易热门","commentNum":"1600"...
# 9  {"type":"市场","site":"中证网","commentNum":"0","jo...
#
#                            title  \
# 0           小米MIUI 9首批机型曝光：共计15款
# 1     骁龙835在Windows 10上的性能表现有望改善
# 2      一加手机5细节曝光：3300mAh、充半小时用1天
# 3  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
# 5                 金融股一枝独秀 配置价值犹存
# 6            配骁龙660 全面屏鼻祖夏普新机酝酿中
# 7                博友早评：震荡有利消化套牢筹码
# 8       武汉千余警察出动 抓获808名俊男靓女全是诈骗犯
# 9            纳入MSCI指数 A股长期配置价值提升
#
#                                                  url
# 0     http://www.cnbeta.com/articles/tech/623597.htm
# 1     http://www.cnbeta.com/articles/tech/623599.htm
# 2     http://www.cnbeta.com/articles/tech/623601.htm
# 3  http://world.huanqiu.com/hot/2017-06/10866126....
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...
# 5  http://www.cs.com.cn/gppd/201706/t20170623_533...
# 6     http://www.cnbeta.com/articles/tech/623603.htm
# 7  http://www.cs.com.cn/gppd/201706/t20170623_533...
# 8  http://news.163.com/17/0614/14/CMT9N8G80001899...
# 9  http://www.cs.com.cn/gppd/201706/t20170623_533...

# %%
data.loc[0,['feature']]
# Out:
# feature    {"type":"科技","site":"cnbeta","commentNum":"37"...
# Name: 0, dtype: object

# %%
def clock(func):
    def clocked(*args, **kwargs):
        t0 = timeit.default_timer()
        result = func(*args, **kwargs)
        elapsed = timeit.default_timer() - t0
        name = func.__name__
        arg_str = ', '.join(repr(arg) for arg in args)
        print(elapsed,'s')
        #print('[%0.8fs] %s(%s) -> %r' % (elapsed, name, arg_str, result))
        return result
    return clocked

# %%
def typeof(variate):
    type=None
    if isinstance(variate,int):
        type = "int"
    elif isinstance(variate,str):
        type = "str"
    elif isinstance(variate,float):
        type = "float"
    elif isinstance(variate,list):
        type = "list"
    elif isinstance(variate,tuple):
        type = "tuple"
    elif isinstance(variate,dict):
        type = "dict"
    elif isinstance(variate,set):
        type = "set"
    print(type)
    return type

# %% [markdown]
# # INPUT: Which is more useful, more efficient ?

# %%
@clock
def get_size(data, attributes):
    size = 0
    data = data[attributes]
    for i in range(len(data)):
        if isinstance(data[i],str):
            size = size + len(data[i])
    return size, size/len(data)

attributes = ['content','feature', 'title','author','url']
#attr_choosen = ['content','feature', 'title','author','url']
attr_choosen = ['content']
show = [print( i, get_size(data,i)) for i in attributes]
# Out:
# 2.559933386999546 s
# content (38729226, 432.1927665130397)
# 2.6356201079997845 s
# feature (53450994, 596.4780439901351)
# 2.5343696729996736 s
# title (2123231, 23.69386570845097)
# 2.268567680999695 s
# author (505494, 5.6409815759225985)
# 2.3123578319991793 s
# url (7472901, 83.39267500641662)

# %% [markdown]
# # INPUT: How do we handle the imbalance?

# %%
data_sampled = data.sample(n=3000)
data_pos = data_sampled[data_sampled['source'].str.contains('新华')]
print(len(data_pos))
print(len(data_pos)/len(data_sampled))
# Out:
# 2639
# 0.8796666666666667

# %% [markdown]
# # 样本均衡
# ## 直接的选择数据，使其满足需求
# ## 分类器的weight设置
# ## produce the examples u need

# %%
data['source'] = data['source'].fillna('')
data_pos = data[data['source'].str.contains('新华')]
data_neg = data[data['source'].str.contains('新华') == 0]

#n = 5000
N_sample = 6000
data_neg = data_neg.sample(n = (int)(N_sample/2))
data_pos = data_pos.sample(n = (int)(N_sample/2))

data_sampled = data_pos.append(data_neg)
print(len(data_sampled))


# N, 3:1, 5:2, 
#5000,1:1
#20000 1:1
#30000 2:1
#30000
#print(len(data_pos))
#print(len(data) - len(data_pos))
# Out:
# 6000

# %% [markdown]
# # 预处理，去标点，加label

# %%
def cut(string):
    return ' '.join(jieba.cut(re.sub(r'[^\w\s]',' ',string.strip())))
def preprocess(data):
    for attr in attributes:
        data[attr] = data[attr].fillna('').apply(cut)
    data['is_xinhua'] = np.where(data['source'].str.contains('新华'),1,0)
    #print(data)
    x_inputs = data.loc[:,attr_choosen]
    #print(x_inputs)
    y_inputs = data['is_xinhua'].values
    #print(y_inputs)
    return x_inputs,y_inputs
x_inputs, y_inputs = preprocess(data_sampled)       
#print(data_processed)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.930 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# # max_features
# # 'today is a good day'-->[1,3,2,4,5]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#x_inputs = data_processed.loc[:,attr_choosen]
#print(inputs)
#y_inputs = data_processed['is_xinhua'].values
#print(labels)
@clock
def vectorize(x_inputs, attr_choosen):
    vectorizer = TfidfVectorizer(max_features=5000, token_pattern=r"(?u)\b\w+\b", max_df = 1.0,
                                 stop_words = None,vocabulary = None )# (?u)进入re.u，unicode匹配模式，https://stackoverflow.com/questions/35043085/what-does-u-do-in-a-regex
    vec = None
    for attr in attr_choosen:
        vec_fea = vectorizer.fit_transform(x_inputs[attr].values)
        print("vocabulary\n",vectorizer.vocabulary_, len(vectorizer.vocabulary_))
        print("stop_words\n",vectorizer.stop_words_, len(vectorizer.stop_words_))
        #typeof(vec_fea)
        #np_vec = np.array(vec_fea)
        np_vec = vec_fea.toarray()
        #print(np_vec)
        if vec is None:
            vec = np_vec
        else:
            vec = np.hstack((vec,np_vec))
        #print(attr, vec_fea.shape, np_vec.shape)
    return vec

x_vecs = vectorize(x_inputs, attr_choosen)
print(x_vecs.shape)
# Out:
# vocabulary
#  {'公开': 934, '金额': 4707, '文物': 2797, '四个': 1564, '充满': 866, '民营': 3209, '净值': 1020, '旧': 2871, '往往': 2333, '评估': 4286, '靠': 4840, '违法行为': 4582, '1500': 23, '能够': 4023, '群众': 3962, '安装': 1948, '民生': 3208, '试验': 4300, '绿': 3921, '城': 1684, '石墨': 3665, '震荡': 4828, '总数': 2393, '研制': 3669, '房地产': 2497, '深圳市': 3339, '仅为': 652, '突破': 3760, '研发': 3670, '沿海': 3258, '创意': 1098, '肯定': 4013, '物资': 3437, '行政': 4165, '南安普敦': 1269, '认知': 4248, '2016': 46, '冠军': 1008, '于是': 568, '河南': 3252, '指数': 2626, '62': 107, '专业化': 364, '盲人': 3604, '据统计': 2646, '科研人员': 3719, '色彩': 4076, '到': 1115, '引入': 2280, '广大': 2227, '属于': 2104, '全体': 896, '影院': 2330, '青岛': 4831, '韩国': 4850, '吴': 1503, '不如': 337, '出现': 1054, '一年': 211, '节': 4079, '现状': 3482, '景观': 2924, '两大': 406, '十条': 1236, '夏普': 1743, '申报': 3530, '摆脱': 2709, '有利于': 2975, '频频': 4875, '意向': 2430, '年龄': 2213, '中期': 454, '形态': 2323, '同学': 1467, '购房': 4367, '难': 4809, '图片': 1633, '首席': 4906, '回归': 1580, '身份': 4467, '温暖': 3353, '减产': 1026, '服务中心': 2997, '鲜明': 4961, '高层次': 4940, '药物': 4113, '各个': 1434, '课题': 4326, '觉得': 4226, '加工': 1166, '软件': 4490, '中证网': 458, '南极': 1273, '下行': 318, 'ｐ': 4996, '家': 2001, '场所': 1669, '养殖': 977, '更新': 2940, '本土': 3021, '来自': 3077, '钢铁': 4713, '船': 4071, '东森': 390, '吉林': 1462, '尚未': 2067, '李显龙': 3058, '跌幅': 4439, '赛': 4395, '确实': 3683, '芬兰': 4085, '历史': 1303, '平': 2190, '集群': 4819, '过剩': 4516, '倍': 825, '故事': 2758, '级': 3851, '购物': 4369, '几年': 1037, '不敢': 345, '质疑': 4360, '汽车': 3240, '下滑': 317, '事宜': 551, '落实': 4136, '北美': 1213, '法国': 3261, '天': 1829, '2017': 47, '立足': 3766, '写道': 994, '主流': 491, '规则': 4214, '委托': 1902, '稳健': 3741, '恶劣': 2411, '合法权益': 1454, '观察': 4209, '望京': 3000, '回应': 1579, '不想': 342, '动能': 1183, '军舰': 1000, '一座': 213, '打开': 2526, '河北省': 3251, '将来': 2045, '尽管': 2081, '黑色': 4967, '正如': 3157, '分布': 1069, '确保': 3681, '乡镇': 529, '亿美元': 649, '高峰论坛': 4941, '以下': 679, '一期': 222, '智慧': 2926, '23': 53, '均价': 1672, '央企': 1843, '异地': 2277, '因': 1590, '注册': 3278, '航展': 4063, '币': 2153, '博': 1278, '接触': 2667, '关闭': 964, '硬件': 3680, '本身': 3034, '航母': 4064, '常州': 2180, '广西': 2232, '绝大多数': 3907, '过': 4515, '球迷': 3495, '记得': 4260, '扩大': 2536, '尤文图斯队': 2071, '国土': 1612, '发射': 1355, '姓名': 1897, '投资': 2568, '强调': 2302, '菲律宾': 4124, '务实': 1175, '面': 4841, '财务': 4345, '澎湃': 3382, '评级': 4288, '15': 21, '生长': 3519, '显得': 2911, '某某': 3095, '种子': 3710, '海口市': 3313, '覆盖': 4202, '转债': 4480, '提振': 2688, '失踪': 1849, '大多': 1792, '展出': 2099, '很少': 2341, '都': 4668, '队': 4751, '国务院': 1611, '调查': 4330, '图文': 1632, '经过': 3893, '庆祝': 2234, '货运': 4358, '显然': 2912, '说': 4313, '中超联赛': 461, '短信': 3661, '传递': 731, '到达': 1120, '改革开放': 2744, 'ofo': 174, '海信': 3307, '建议': 2260, '理解': 3501, '篮球': 3821, '吗': 1491, '苏丹': 4090, '充分发挥': 865, '８': 4983, '手机': 2513, '改革': 2743, '监管': 3593, '仪式': 689, '路': 4452, '至': 4050, '白色': 3578, '150': 22, '瑞士': 3506, '住宅': 750, '水上': 3221, '兑': 880, '从而': 668, '红': 3844, '停': 849, '言论': 4234, '赛后': 4399, '回报': 1582, '驻': 4925, '资金': 4390, '78': 124, '账户': 4353, '稳定': 3742, '敌': 2764, '警察': 4237, '全部': 916, '尼斯': 2079, '加入': 1163, '医改': 1224, '街头': 4169, '大气污染': 1809, '曾': 2946, '增多': 1711, '没': 3245, '进步': 4572, '新高': 2826, '保持': 805, '多少': 1771, '16': 24, '原': 1306, '不仅': 326, '上台': 290, '赛区': 4398, '针对性': 4711, '负': 4337, '公积金': 943, '价值': 693, '容易': 2012, '超市': 4428, '创业': 1092, '形成': 2324, '飞行': 4887, '供给': 782, '可谓': 1419, '一对': 209, '转型': 4484, '名': 1476, '救助': 2766, '电力': 3534, '信用卡': 819, '基点': 1700, '茶叶': 4105, '率': 3458, '总是': 2394, '维权': 3919, '司机': 1430, '20': 30, '500': 90, '英国': 4094, '动物': 1181, '链': 4723, '部': 4662, '待': 2337, '营业': 4127, '或者': 2475, '经典': 3880, '方面': 2834, '苏州': 4092, '对外开放': 2023, '极端': 3085, '就是': 2074, '今天': 656, '肖骁': 4003, '弩': 2292, '开幕式': 2270, '今年以来': 658, '注明': 3280, '可能': 1417, '第六': 3795, '次': 3145, '业绩': 385, '报道': 2577, '高明区': 4947, '地面': 1666, '相当于': 3619, '共建': 952, '痛苦': 3571, '这里': 4563, '较量': 4501, '56': 97, '负债': 4338, '但是': 739, '汇率': 3230, '计划': 4239, '链条': 4724, '凸显': 1042, '新华社摄影部': 2812, '公交车': 920, '年内': 220 ...
# stop_words
#  {'冷静下来', '一周年', '丢进', '钱德勒', '少儿读物', '剐', '出苗', '伊犁', '嘿', '英因', '本国', '石材', '警匪片', '猪圈', '果脯', '上峰', '东瓦希', '疑问', '忧愁', '唐突', '北海市', '刑侦', '载歌载舞', '近两年来', '推以', '小分队', '外贸出口', '获益者', '银价', '刮掉', '村内', '东贝', '校企', '多大', '汉人', '狼来了', '温尼伯', '冰岛', '占场', '丁乃竺', '天然', '破灭', '参展商', '因台', '细才', '技术能手', '副行长', '几例', '脚疼', '紫外线', '兼容性', '废寝忘食', '索回', '案内', '未能如愿', '几千块', '终审', '亨', '终端用户', '德索萨', '国宏金桥', '基线', '几十元', '岩田', '卡比尔', '两化', '日裔', '富足', '边界', '等涉', '王后', '瘦骨嶙峋', '6666', '饥寒', '葫芦', '阜城县', '1210', '凌广志', '蟒蛇', '亚洲地区', '益农', '东边', '太近', '栓栓', '第一艘', '民间团体', '彩石', '工业部长', '春晓', '侯红义围', '管员', '决不会', '爆', '鹤', '陌生感', 'game', '善解人意', '曼城', '归', '旅居', '鸽派', '松伟', '对焦', '将领', '花漾', '电解铝', '政务司', '刑警', '李斯特', '变速箱', '边陲', '小虎岛', '乘乱', '夹层', '参保', '泥潭', '交响音乐', '市委书记', '十指关', '期盼', '多片', '英', '巴斯克', '大龙', '投币', '熟知', '蔡春芝', '围捕', '送礼', '拂过', '揉', '天书', '截瘫', '承载力', '滴灌', '沾染上', '迪赫', '应定', '司法解释', '413', '啃', 'reception', '引号', '舱室', '再付', '他拿球', '旋木鸟', '富尔兹', '一升', '四类', '钱小军', '特区建设', '汪军', '哥伦比亚特区', '国际石油', '赶时间', 'api', '刚一', '何先生', '被删', '中多放', '二十亿', '相差太多', 'mtn2', 'u16', '不放', '小儿麻痹症', '3818', '动议', '好几位', '驻会', '形神', '顾住', '集装箱', '临深', '1941', '中央实验话剧院', '理不糙', '一顶', '三农', '前一天', '投用', '蛇者乎', '见过', '所在城市', '陈宏麟', '解放前', '冯仑', '热力', '撞见', '内多', '防治法', '拉克斯', '受害者', '紧跟', '主扫', '3791', '徐彪', '希洛', '神速', '雕塑公园', '有害信息', '市同', '听力', '4811', '音调', '外海', '抵税', '领投方', '印出来', '每起', '咱', '指教', '丁克', '盲点', '百合', '生存能力', 'iot', '茶浴', '美眉', '追悔', '国家信访局', '妻妹', '紧', '风和帆', '俊逸', '岗位培训', '基因组学', '水力', '计算器', '最南到', '选号', '低级', '水力资源', '与非', '练球', '羽', '小涨', '聚会', '卡用', '叛乱分子', '受海', '仍未见', '老款', '惊叹不已', '温吞', '改版', '深蓝色', '钟祥', '斯托雷', '先声', '光标', '能源行业', '众木', '抛锚', '新钢', '戳穿', '支柱产业', '刘章', '两纵', '政治学家', '导引', 'cnfin', '最高法院', '转晴', '种牙', '荣辱', '段泊岚二村', '难住', '铁路网', '东洋', '保不住', '请战', '枯枝败叶', '世外桃源', '衰落', '拉拔', '兴合村', '谷爱武', '钢铁价格', '三分球', '加提成', '这三类', '对张', '汤包', '姜义亮', '鹿吹', '为伴', '电流', '陕西历史博物馆', '华自', '乐呵呵', '楚水间', '古德温', '感怀', '绿地面积', '发包方', '美通', '可悲', '爱美', '没法', '姚', '开封市', '疏忽大意', '膨大', '汲取', '以电代', '哈杜尔', '英国国防部', '放风', '稍作', '养蜂业', '哲在', '脊柱炎', '晖映', '陈国桃', '咖', 'wong', '喀纳斯湖', '何祥美', '李成', '3118', '朝鲜战争', '1900', '哗然', '阻滞', '审理案件', '法规性', '付诸行动', '李磊', '夭折', '1994', '火山岩', '三角梅', '宝岛', '处决', '杯水车薪', '斯蒂', '站票', '老天', '别有用心', '喝一杯', '叶三石', '交互方式', '考间', '出一波', '只出', '散风', '精确性', '夜归人', '欠压', '432', '1291', '充分说明', '名曰', '3090', '若尔盖', '泗洪县', '晚自习', '本片', '野外工作', '派发', '茂南区', '查阅', '食用菌', '中乒赛', '爆射', '玉川', 'bat', '20138', '保税区', '土坡', '黄石市', '杨正江', '成长型', '先遣', '独立性', '大表', '臂', '停步', '几段', '旧厂', '制者', '高风', '烤海', '三五次', 'evaluatepharma', '库班', '老板娘', '脐', '勒马', '季米特洛夫', '垄港', '蚍蜉撼大树', '邬', '伊利', '划给', '拉长', '可治', '纺线', '易安', '国防科技', '搭乘', '衬衣', '大火', '十二生肖', '斩获', '切入', '人常', '趣味', '未至', '打到', '双重身份', '瓦雷拉', '促天', '肺动脉', '掌权', '恶行', '一二十年', '邱越', '这则', '老房子', '万分钟', '总裁兼', '井然有序', '数据业务', '调阅', '田冬梅', '脏乱', '解编', '1977', '用户服务', '不同之处', '懒', '北京钓鱼台国宾馆', '化学反应', '华标峰', '到场', '华大基因', '互为', '天信', '树新风', '比克', '彭介林', '毛飞廉', '可降', '越王', '宋永武', '外务省', '第五次', '深圳机场', '打拐', '鲁尼说', '失职', '马杜赖', '修法', '高不可攀', '文森', '中山陵园', '拼颜值', '越唱', '局级', '徐剑梅', '专为', '搏击', '装睡', '苏绣', '翻到', '曾为', '渝北', '而酷', '特意', '发文', '竹织', '落下', '察布查尔锡伯自治县', '争相', '电子系统', '谢钦', '去年初', '进光量', '中国残疾人福利基金会', '李东生', '纲', '冷性', '嗜', '分众传媒', '稠', '人永隔', '老家伙', '自尊', '资历', '信者', '审查逮捕', '变天', '俘虏', '惊诧不已', '连身', '科学论文', '远嫁', '拉伸', '延平', '胚胎学', '惠', '市州', '投资决策', '鳕鱼', '颈椎', '隧', 'littleflower', '出入境', '击发', '希腊神话', '世界卫生组织', '所独', '花茶', '非常规', '教学点', '中性', '蓬头垢面', '大雨天', '5446', '挑到', '一日为师', '前途无量', '第二份', '探路者', '上海社科院', '客等', '药剂科', '跳过', '户非', '国史', '报国', '邱义升', '母', '服装学院', '海石', '狄龙', '瑞贝卡', '尽力', '我错', '暴食', '松骨峰', '安逸', '广莱坞', '跑速', '刘洪选', '瓦格纳', '措辞', '这架', '维修厂', '开端', '超前', '突外', '6759', '回家吧', '调解', '财物', '李嘉明', 'ren', '能拉上', '564', '疲劳', '转倒', '哈坎达', 'pro', '张璇', '乱画', '甚大', '缺斤少两', '鬼天气', '后来居上', '王振有', '低密度', '名下', '家用空调', '曹玲娟', '分不开', '公牛队', '修例', '橡皮', '证满', '晋龙园', '咖啡屋', '一走了之', '吴胜武', '其以', '东到', '我选', '胸', '白露', '无线电', '李珥', '格伦费尔', '起于', 'he ...
# 3.0047245909991034 s
# (6000, 5000)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(
    x_vecs , y_inputs, train_size = 0.8, test_size=0.2)

# %% [markdown]
# # Evaluation metrics

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
@clock
def get_performance(clf, x_, y_):
    y_hat = clf.predict(x_)
    print('f1_score is: {}'.format(f1_score(y_, y_hat)))
    print('accuracy is: {}'.format(accuracy_score(y_, y_hat)))
    print('percision is: {}'.format(precision_score(y_, y_hat)))
    print('recall is: {}'.format(recall_score(y_, y_hat)))
    #print('roc_auc is: {}'.format(roc_auc_score(y_, y_hat)))
    #print('confusion matrix: \n{}'.format(confusion_matrix(y_, y_hat, labels=[0, 1])))

# %%
from sklearn.neighbors import KNeighborsClassifier
@clock
def KNN(x_train, y_train):
    clf = KNeighborsClassifier(n_neighbors = 5, weights = 'uniform', algorithm = 'auto')
    clf.fit(x_train, y_train)
    return clf
#clf.fit(X_test,y_test)
get_performance(KNN(x_train,y_train),x_test,y_test)
# Out:
# 1.1603996230005578 s
# f1_score is: 0.6192090395480226
# accuracy is: 0.7191666666666666
# percision is: 1.0
# recall is: 0.44844517184942717
# 50.9136662359997 s

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
@clock
def KNN(x_train, y_train):
    clf = KNeighborsClassifier()
    param_grid = { 'n_neighbors' : [i for i in range(1,3)]}
    grid = GridSearchCV(clf, param_grid, cv = 2, scoring='accuracy',n_jobs = -1)
    clf = grid.fit(x_train, y_train)
    clf.fit(x_train, y_train)
    print(clf.best_params_)
    return clf
#clf.fit(X_test,y_test)
get_performance(KNN(x_train,y_train),x_test,y_test)
# Out:
# {'n_neighbors': 1}
# 197.6106646870012 s
# f1_score is: 0.7561697926949654
# accuracy is: 0.7941666666666667
# percision is: 0.9527363184079602
# recall is: 0.6268412438625205
# 42.229468202000135 s
